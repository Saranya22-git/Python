# %% [markdown]
# bool
#
# 'bool' is an immutable type.
#
# 'bool' is one of the predefined class name and treated as fundamental data type.
#
# The purpose of bool data type value is "To store TRUE, FALSE values."
#
# In python programming TRUE FALSE are called keywords and it is treated as value of bool data type.
#
# In python programming internally the value of True is treated is 1 and false is treated as 0.

# %%
a=True
b=True

print(a,id(a))
print(b,id(b))
# Out:
# True 140728191798016
# True 140728191798016

# %%
a=True
b=a

print(a,id(a))
print(b,id(b))
# Out:
# True 140728191798016
# True 140728191798016

# %%
a=True
b=bool(1)

print(a,id(a))
print(b,id(b))
# Out:
# True 140728191798016
# True 140728191798016

# %%
a=True+False
b=bool(1+0)

print(a,id(a))
print(b,id(b))
# Out:
# 1 140728192705656
# True 140728191798016

# %%
a=True+False
b=bool(True+False)

print(a,id(a))
print(b,id(b))
# Out:
# 1 140728192705656
# True 140728191798016

# %%
a=True+False
b=bool(1+0)

print(a,id(a),type(a))
print(b,id(b),type(b))
# Out:
# 1 140728192705656 <class 'int'>
# True 140728191798016 <class 'bool'>
