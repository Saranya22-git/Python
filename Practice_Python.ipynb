# %%
print("Hello Python")
print(10+20)
print(type(100))
print(type(10.5))
print(type(True))
# Out:
# Hello Python
# 30
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %%
a=10
b='10'

print(type(a))
print(type(b))
# Out:
# <class 'int'>
# <class 'str'>
