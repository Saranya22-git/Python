# %%
sara_=45
print(sara_)
print("------")
# Special Symbols are not allowed except UNDERSCORE(_)

    #sara@=45
    #sara@--------SyntaxError

    #sara dd=34
    #sara dd------SyntaxError

# Cannot use Keywords as Variable Names

    #if=34
    #if----------SyntaxError

# Case-Sensitive

    #Age=45
    #age=45

# The correct way
s="good"
print(s)
print("------")

__si=5678
print(__si)
