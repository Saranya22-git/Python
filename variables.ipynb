# %%
sara_=45
print(sara_)
# Special Symbols are not allowed except UNDERSCORE(_)

    #sara@=45
    #sara@--------SyntaxError

    #sara dd=34
    #sara dd------SyntaxError

# Cannot use Keywords as Variable Names

    #if=34
    #if----------SyntaxError

# Case-Sensitive

    #Age=45
    #age=45
# Out:
# 45

# %%
s="good"
print(s)
# Out:
# good

# %%
__si=5678
print(__si)
# Out:
# 5678
