# %% [markdown]
# What are **Python data types**?
#
# Data types define the type of value a variable holds.

# %%
# How to check data type?

x=10
print(type(x))
# Out:
# <class 'int'>

# %%
'''
Difference between List and Tuple
List-Mutable, Tuple-Immutable
List Syntax-[],Tuple Syntax-()
List is slower compared to tuple

'''

# %% [markdown]
# What is None?
#
# `x=None`
#
# Represents no value/null

# %% [markdown]
# What is bool?
#
# True, False
#
# Subclass of int: True=1,False=0

# %% [markdown]
# Mutable-list,dict,set
#
# Immutable-int,str,float,tuple,frozenset

# %%
a = [1,2]
b = [1,2]

print(a == b)  
print(a is b)
# Out:
# True
# False

# %%
# Can tuple have mutable elements?

t=([1,2],3)
t[0].append(0)

print(t)
# Out:
# ([1, 2, 0], 3)

# %%
print(bool([]))
print(bool([1]))
# Out:
# False
# True

# %%
print(bool(0), bool(1), bool(-1))
# Out:
# False True True

# %%
print(type(10/2))
# Out:
# <class 'float'>

# %%
#-----INT-----
a=34
b=34
print(a,id(a))
print(b,id(b))
# Out:
# 34 140728137853080
# 34 140728137853080

# %%
c=45
d=c
print(c,id(c))
print(d,id(d))
# Out:
# 45 140728137853432
# 45 140728137853432

# %%
a=123455
b=123455
print(a,id(a))
print(b,id(b))
# Out:
# 123455 1235428747312
# 123455 1235428746608

# %%
a=1
b=True+False
print(a,id(a))
print(b,id(b))
# Out:
# 1 140728137852024
# 1 140728137852024

# %%
a=257
b=257
print(a,id(a))
print(b,id(b))
# Out:
# 257 1235428747920
# 257 1235428746864

# %%
a=21234
b=a
print(a,id(a))
print(b,id(b))
# Out:
# 21234 1235428748048
# 21234 1235428748048

# %%
a=257
b=a
print(a,id(a))
print(b,id(b))
# Out:
# 257 1235428747920
# 257 1235428747920

# %%
a=True
b=1
print(a,id(a),type(a))
print(b,id(b),type(b))
# Out:
# True 140728136944384 <class 'bool'>
# 1 140728137852024 <class 'int'>

# %%
if __name__ == '__main__':
    n = int(input())
    if n<0:
        print("It is invalid")
    else:
        for i in range(1,n+1):
            print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
